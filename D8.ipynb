# %%
#Loading in code and data
from kinetic import KineticScan
from spatialScan import SpatialScan
from ss import SpatiallySeparated
import matplotlib.pyplot as plt
import glob
import re
import numpy as np
import time

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
x0 = 0
xend = 20

kinPATH = glob.glob('D8/**/*KIN.dat', recursive=True)
kinObjs = []
for k in kinPATH:
    fname = re.search('[\\\/][^\\\/\n]+.dat', k)[0][1:-4]
    ko = KineticScan(k, label=fname)
    p = ko.customFit(x0, xend)
    kax = ko.visualize()
    ko.plotFit(ax=kax, x0=x0, xend=xend, params=p)
    kax.set_title(fname)
    plt.savefig(f'D9/outputs/{fname}.png')
    plt.show()
    kinObjs.append(ko)
# Out:
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="700">

# %%
span = kinObjs[0].interactiveVis()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
